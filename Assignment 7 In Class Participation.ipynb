# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users/Nanda/Downloads/03-31-2020.csv')

# %%
df.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-03-31 23:43:56
# 1  22001.0     Acadia       Louisiana             US  2020-03-31 23:43:56
# 2  51001.0   Accomack        Virginia             US  2020-03-31 23:43:56
# 3  16001.0        Ada           Idaho             US  2020-03-31 23:43:56
# 4  19001.0      Adair            Iowa             US  2020-03-31 23:43:56
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          4       0          0       0
# 1  30.295065  -92.414197         39       1          0       0
# 2  37.767072  -75.632346          7       0          0       0
# 3  43.452658 -116.241552        195       3          0       0
# 4  41.330756  -94.471059          1       0          0       0
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# ...

# %%
dataset1 = df.groupby(['Province_State']).sum()
dataset1.sort_values("Confirmed", ascending = False,
inplace=True)
dataset1.head()
# Out:
#                      FIPS          Lat        Long_  Confirmed  Deaths  \
# Province_State
# New York        2019404.0  2389.536539 -4229.693579      75833    1550
# Hubei                 0.0    30.975600   112.270700      67801    3187
# New Jersey       714441.0   846.015259 -1567.071444      18696     267
# California       290824.0  1795.311328 -5787.848423       8210     173
# Michigan        1773810.0  2971.190821 -5777.476718       7615     259
#
#                 Recovered  Active
# Province_State
# New York                0       0
# Hubei               63153    1461
# New Jersey              0       0
# California              0       0
# Michigan                0       0

# %%
dataset1[['Confirmed', 'Deaths']].head(10).plot.bar(title="Comparison of Top 10 States Confirmed Cases VS Deaths in the World as on 31st March 2020")
